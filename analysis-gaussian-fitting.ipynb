# %%
from spectra import Spectrum

# %% [markdown]
# ## First spectrum - idid000007077jd2458163p6789f000
# Expected velocity: 39.19 +- 3.3 km/s

# %%
print("First spectrum")
spec1 = Spectrum('data-spectrum/new/idid000007077jd2458163p6789f000.fits')
spec1.plot()
spec1.gfitting([4861.297761, 6562.85175,8502.49, 8545.38, 8598.39,8665.02, 8750.46], True)
# Out:
# First spectrum
# Wavelength: 4861.297761
# Wavelength: 6562.85175
# Wavelength: 8598.39
# 43.33165584325953 +/- 2.1298448350022103 km/s
# [39.22695509737073, 43.51534027077851, 47.2910397264601]
# [6.5495850270416085, 2.3480204282716994, 7.967570141836727]

# %% [markdown]
# ## Second spectrum - idid000004031jd2458163p6789f000 : Best spectrum so far
# Espected velocity (from spexxy) for log g = 1.6: 42.94 +- 2.8 km/s

# %%
print("Second spectrum")
spec2 = Spectrum('data-spectrum/new/idid000004031jd2458163p6789f000.fits')
spec2.plot()
spec2.gfitting([4861.297761,6562.85175,8498.02,8542.09,8662.14])
# Out:
# Second spectrum
# 44.22514194686247 +/- 1.494407861456024 km/s
# [64.08051089671005, 41.715009294401995, 46.65284886384945, 46.202888036891075, 40.95021686094739]
# [7.040937792340175, 2.6507553468877267, 8.458448072246757, 2.5444633707242024, 2.9253655962097778]

# %% [markdown]
# # SPECTRUM idid000001330jd2458163p6789f000

# %%
spec3 = Spectrum('data-spectrum/old/idid000001330jd2458163p6789f000.fits')
spec3.plot()
spec3.gfitting([4861.297761, 6562.85175,8502.49, 8545.38, 8598.39,8665.02, 8750.46])
# Out:
# 38.79424713339719 +/- 3.172155990886294 km/s
# [32.728862756952104, 41.0225849703302, 43.18095960637481]
# [4.996703933811707, 11.167166626248552, 4.414829028114191]

# %% [markdown]
# # SPECTRUM idid000003632jd2458163p6789f000 (third)

# %%
spec = Spectrum('data-spectrum/third_batch/idid000003632jd2458163p6789f000.fits')
spec.plot()
spec.gfitting([6562.8518,8498.02,8542.09,8662.14])
# Out:
# 45.02817798188254 +/- 3.3494712878472552 km/s
# [34.353113855014165, 63.77868080251046, 49.546310078762936]
# [4.506011863561598, 6.417684807636827, 8.005353029896487]

# %% [markdown]
# # SPECTRUM idid000004260jd2458163p6789f000

# %%
spec = Spectrum('data-spectrum/third_batch/idid000004260jd2458163p6789f000.fits')
#spec.plot()
spec.gfitting([4861.2978,6562.85175,8498.02,8542.09,8662.14])
# Out:
# 10.718727787243827 +/- 6.135565770340003 km/s
# [-43.67385974045707, 40.601797260928244, 10.790253969763127]
# [12.08451893901549, 8.963455496681638, 11.728531523826623]

# %% [markdown]
# # SPECTRUM idid000006156jd2458163p6789f000

# %%
spec= Spectrum('data-spectrum/third_batch/idid000006156jd2458163p6789f000.fits')
spec.plot()
spec.gfitting([4861.2978,6562.85175,8498.02,8542.09,8662.14])
# Out:
# 44.109285335826634 +/- 2.0600484171610645 km/s
# [58.05568616832936, 40.01783374811802, 44.95401411817119, 45.4325754047393, 47.18144266303555]
# [19.218500098505885, 3.3928366211896503, 7.793247525488402, 4.304778008676327, 3.636213565976733]

# %% [markdown]
# # SPECTRUM idid000006218jd2458163p6789f000

# %%
spec= Spectrum('data-spectrum/third_batch/idid000006218jd2458163p6789f000.fits')
spec.plot()
spec.gfitting([4861.2978,6562.85175,8437.95,8467.26, 8502.49, 8545.38, 8598.39,8665.02, 8750.46, 8862.89], True)
# Out:
# Wavelength: 4861.2978
# Wavelength: 6562.85175
# Wavelength: 8862.89
# 32.02239224912344 +/- 4.678122490056795 km/s
# [30.179597495570437, 38.74769962418006, 31.73738308200575]
# [7.2449782358420745, 12.812960207899147, 6.9755932620385]

# %% [markdown]
# # SPECTRUM idid000006412jd2458163p6789f000

# %%
spec= Spectrum('data-spectrum/third_batch/idid000006412jd2458163p6789f000.fits')
spec.plot()
spec.gfitting([4861.2978,6562.85175,8437.95,8467.26, 8502.49, 8545.38, 8598.39,8665.02, 8750.46, 8862.89])
# Out:
# 32.2075528888371 +/- 2.56586262258484 km/s
# [37.27864851933418, 30.535595092714313, 31.468620032461903, 32.72487063637047]
# [5.719588809860208, 3.652467277228805, 4.83807974316147, 16.571829621537752]

# %% [markdown]
# # Daniel's spectrum

# %%
dspec = Spectrum("daniel's-spectrum/idid000007172jd2458163p6789f000.fits")
#dspec.plot()
dspec.gfitting([4861.297761,6562.85175], True)
# Out:
# Wavelength: 4861.297761
# Wavelength: 6562.85175
# -8.851741183815193 +/- 4.8700759643614315 km/s
# [-31.723001129875406, 10.975252713995035]
# [7.14681197476833, 6.654198436085145]
